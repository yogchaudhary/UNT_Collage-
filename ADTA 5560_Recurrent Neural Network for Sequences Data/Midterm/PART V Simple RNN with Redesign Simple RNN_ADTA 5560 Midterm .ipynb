# %% [markdown]
# # Report on Training, Evaluation, and Results of  Redesign the Simple RNN

# %% [markdown]
# # Introduction
#
# The purpose of this project was to build, train, and evaluate a Simple Recurrent Neural Network (RNN) to predict values in a sine wave sequence. The sine wave data was generated by dividing the range from 0 to 50 into 768 evenly spaced data points. The dataset was used to train a simple RNN model with 64 neurons in the SimpleRNN layer and a final fully connected (Dense) layer. This report details the steps taken, model performance, and results of the project.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from sklearn.preprocessing import MinMaxScaler
# Out:
# 2024-11-09 23:09:41.561510: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-11-09 23:09:41.561554: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # Step 1: Generate Sine Wave Data

# %%
x = np.linspace(64, 128, 256)  # Generate 256 data points between 0 and 50
y = np.sin(x)  # Sine function to generate sine wave data

# %% [markdown]
# # Step 2: Prepare Training and Testing Data

# %%
train_size = int(len(x) * 0.7)  # 70% for training, 30% for testing
test_size = len(x) - train_size

x_train = y[:train_size]
x_test = y[train_size:]

# %% [markdown]
#  # Normalize the data using MinMaxScaler to ensure that values are between 0 and 1

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
x_train = scaler.fit_transform(x_train.reshape(-1, 1)).flatten()
x_test = scaler.transform(x_test.reshape(-1, 1)).flatten()

# %% [markdown]
# # Prepare the data for the RNN model (use a sliding window approach)

# %%
sequence_length = 10  # Each input sequence will have 10 time steps
def create_sequences(data, seq_length):
    x, y = [], []
    for i in range(len(data) - seq_length):
        x.append(data[i:i + seq_length])
        y.append(data[i + seq_length])
    return np.array(x), np.array(y)

x_train, y_train = create_sequences(x_train, sequence_length)
x_test, y_test = create_sequences(x_test, sequence_length)

# %% [markdown]
# # Reshape data to be in the format (samples, time steps, features)

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# # Step 3: Build the Simple RNN Model

# %%
model = Sequential()
model.add(SimpleRNN(64, activation='tanh', input_shape=(sequence_length, 1)))  # Simple RNN layer with 64 units
model.add(Dense(10))  # Fully connected layer with 10 output neurons
# Out:
# 2024-11-09 23:09:43.755868: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2024-11-09 23:09:43.755903: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2024-11-09 23:09:43.755930: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (tf2-keras-ann-vm): /proc/driver/nvidia/version does not exist
# 2024-11-09 23:09:43.756206: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Compile the model

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
# Display the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 64)                4224
#
#  dense (Dense)               (None, 10)                650
#
# =================================================================
# Total params: 4,874
# Trainable params: 4,874
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Step 4: Train the Model

# %%
history = model.fit(x_train, y_train, epochs=50, batch_size=16, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 11/11 [==============================] - 1s 27ms/step - loss: 0.2147 - mae: 0.3638 - val_loss: 0.0923 - val_mae: 0.2587
# Epoch 2/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0633 - mae: 0.2109 - val_loss: 0.0287 - val_mae: 0.1390
# Epoch 3/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0200 - mae: 0.1122 - val_loss: 0.0128 - val_mae: 0.0884
# Epoch 4/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0104 - mae: 0.0804 - val_loss: 0.0087 - val_mae: 0.0756
# Epoch 5/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0063 - mae: 0.0643 - val_loss: 0.0042 - val_mae: 0.0539
# Epoch 6/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0038 - mae: 0.0512 - val_loss: 0.0040 - val_mae: 0.0519
# Epoch 7/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0435 - val_loss: 0.0023 - val_mae: 0.0390
# Epoch 8/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0021 - mae: 0.0376 - val_loss: 0.0019 - val_mae: 0.0359
# Epoch 9/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0016 - mae: 0.0335 - val_loss: 0.0015 - val_mae: 0.0321
# Epoch 10/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0013 - mae: 0.0299 - val_loss: 0.0011 - val_mae: 0.0277
# Epoch 11/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - mae: 0.
# Epoch 35/50
# 11/11 [==============================] - 0s 6ms/step - loss: 5.8443e-05 - mae: 0.0063 - val_loss: 5.4074e-05 - val_mae: 0.0060
# Epoch 36/50
# 11/11 [==============================] - 0s 6ms/step - loss: 5.7511e-05 - mae: 0.0062 - val_loss: 6.5013e-05 - val_mae: 0.0065
# Epoch 37/50
# 11/11 [==============================] - 0s 7ms/step - loss: 5.7456e-05 - mae: 0.0062 - val_loss: 5.7565e-05 - val_mae: 0.0062
# Epoch 38/50
# 11/11 [==============================] - 0s 6ms/step - loss: 5.2404e-05 - mae: 0.0059 - val_loss: 4.4666e-05 - val_mae: 0.0055
# Epoch 39/50
# 11/11 [==============================] - 0s 7ms/step - loss: 5.4560e-05 - mae: 0.0061 - val_loss: 5.4078e-05 - val_mae: 0.0061
# Epoch 40/50
# 11/11 [==============================] - 0s 6ms/step - loss: 4.3164e-05 - mae: 0.0054 - val_loss: 3.9795e-05 - val_mae: 0.0051
# Epoch 41/50
# 11/11 [==============================] - 0s 7ms/step - loss: 4.0846e-05 - mae: 0.0052 - val_loss: 3.5929e-05 - val_mae: 0.0049
# Epoch 42/50
# 11/11 [==============================] - 0s 7ms/step - loss: 3.8205e-05 - mae: 0.0051 - val_loss: 4.0122e-05 - val_mae: 0.0051
# Epoch 43/50
# 11/11 [==============================] - 0s 7ms/step - loss: 4.2457e-05 - mae: 0.0053 - val_loss: 6.4506e-05 - val_mae: 0.0066
# Epoch 44/50
# 11/11 [==============================] - 0s 7ms/step - loss: 7.7118e-05 - mae: 0.0071 - val_loss: 8.8715e-05 - val_mae: 0.0078
# Epoch 45/50
# 11/11 [==============================] - 0s 6ms/step - loss: 6.9381e-05 - mae: 0.0067 - val_loss: 7.2231e-05 - val_mae: 0.0071
# Epoch 46/50
# 11/11 [==============================] - 0s 6ms/step - loss: 5.3249e-05 - mae: 0.0060 - val_loss: 3.9521e-05 - val_mae: 0.0051
# Epoch 47/50
# 11/11 [==============================] - 0s 6ms/step - loss: 4.9463e-05 - mae: 0.0057 - val_loss: 3.2486e-05 - val_mae: 0.0047
# Epoch 48/50
# 11/11 [==============================] - 0s 6ms/step - loss: 2.7632e-05 - mae: 0.0043 - val_loss: 3.6591e-05 - val_mae: 0.0049
# Epoch 49/50
# 11/11 [==============================] - 0s 7ms/step - loss: 2.8751e-05 - mae: 0.0044 - val_loss: 2.6987e-05 - val_mae: 0.0043
# Epoch 50/50
# 11/11 [==============================] - 0s 6ms/step - loss: 2.6382e-05 - mae: 0.0042 - val_loss: 2.8328e-05 - val_mae: 0.0043

# %% [markdown]
# # Step 5: Evaluate the Model

# %%
test_loss, test_mae = model.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")
# Out:
# 3/3 [==============================] - 0s 3ms/step - loss: 2.8328e-05 - mae: 0.0043
# Test Loss: 2.832801874319557e-05, Test MAE: 0.004311683122068644

# %% [markdown]
# # Step 6: Plot Training and Validation Loss

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Step 7: Make Predictions

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# # Plotting Test vs Prediction

# %%
plt.plot(y_test, label='True Values')
plt.plot(y_pred, label='Predicted Values')
plt.legend()
plt.xlabel('Time Steps')
plt.ylabel('Sine Wave Value')
plt.title('True vs Predicted Sine Wave Values')
plt.show()

# %%
# Part #4
